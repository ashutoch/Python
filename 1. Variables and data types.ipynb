# %%
name = "Ashu"
age = 12
height = 5.9
is_new = True

# python automatically detect the type of variable

print(name, age, height, is_new)
print(f"the output using fstring: {name}, {age}, {height}, {is_new}") 
# used when we want to print simple text and data at the same time
# Out:
# Ashu 12 5.9 True
# the output using fstring: Ashu, 12, 5.9, True

# %%
# DATA TYPES
num = 10 # integer
pi = 3.14 # float
name = "Ashu" # string
is_new = False
fruits = ["kiwi", "pear"] #list

# to check data type
print(type (fruits))
type(is_new)
# Out:
# <class 'list'>
# bool

# %%
# practice set to swap 2 numbers 
# a = input("Enter first number: ")
# b = input("Enter second number")

a = 5
b = 10

c = a
a = b
b = c

print("a = ", a, "b = ", b)
# Out:
# a =  10 b =  5

# %%
# practice set to swap 2 number without using third variable
a = 5
b = 10
a, b = b, a

print("a = ", a, "b = ", b)
# Out:
# a =  10 b =  5

# %%
# practice set to make a digital business card (print name, profession and age)

name = input("Enter your name: ")
profession = input("Enter your profession: ")
age = input("Enter your age: ")

print("------------------")
print("Name: ", name)
print("Profession: ", profession) 
print("Age: ", age)
print("------------------")
# Out:
# ------------------
# Name:  Ashu
# Profession:  Student
# Age:  18
